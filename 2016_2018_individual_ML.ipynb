# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)

# %%
accepted = pd.read_csv("accepted_2016_2018_individual.csv")

# %%
accepted.set_index("id", inplace=True)

# %%
accepted["term"].value_counts()
# Out:
#  36 months    696702
#  60 months    267823
# Name: term, dtype: int64

# %%
plt.pie(accepted["term"].value_counts(), labels = ["36 months", "60 months"], autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x121c80b38>,
#   <matplotlib.patches.Wedge at 0x121f562e8>],
#  [Text(-0.7073424283215655, 0.8424171704661244, '36 months'),
#   Text(0.707342349448774, -0.8424172366922987, '60 months')],
#  [Text(-0.38582314272085383, 0.4595002747997042, '72%'),
#   Text(0.38582309969933126, -0.459500310923072, '28%')])

# %%
accepted["home_ownership"].value_counts()
# Out:
# MORTGAGE    475005
# RENT        379546
# OWN         109312
# ANY            662
# Name: home_ownership, dtype: int64

# %%
plt.pie(accepted["home_ownership"].value_counts(), labels = ["Rent", "Mortgage", "Own", "Other"], autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x14ec63e10>,
#   <matplotlib.patches.Wedge at 0x14ec6d5c0>,
#   <matplotlib.patches.Wedge at 0x14ec6dcc0>,
#   <matplotlib.patches.Wedge at 0x14ec80400>],
#  [Text(0.02600014442369453, 1.0996926809295164, 'Rent'),
#   Text(-0.40989083729951753, -1.020778870029107, 'Mortgage'),
#   Text(1.029348118247712, -0.3878691164038386, 'Own'),
#   Text(1.0999974427785835, -0.002371893879815553, 'Other')],
#  [Text(0.014181896958378832, 0.5998323714160998, '49%'),
#   Text(-0.22357682034519136, -0.5567884745613311, '39%'),
#   Text(0.5614626099532973, -0.21156497258391194, '11%'),
#   Text(0.5999986051519546, -0.0012937602980812105, '0%')])

# %%
accepted["emp_length"].value_counts()
# Out:
# 10+ years    350853
# 2 years       96045
# 3 years       85030
# < 1 year      78017
# 1 year        70080
# 4 years       64852
# 5 years       64377
# 6 years       46296
# 7 years       37228
# 8 years       36996
# 9 years       34751
# Name: emp_length, dtype: int64

# %%
plt.figure(figsize=(13, 6))
sns.countplot(x="emp_length", order = ["<1 year", "2 years", "3 years", "4 years", "5 years", "6 years",
                                       "7 years", "8 years", "9 years", "10+ years"], data=accepted)

# %%
plt.figure(figsize=(13, 6))
sns.scatterplot(x="fico_range_low", y="int_rate", hue="grade", estimator="mean", data=accepted)

# %%
sns.catplot(x="grade", y="fico_range_low", order = ["A", "B", "C", "D", "E", "F", "G"], data=accepted)

# %%
sns.catplot(x="grade", y="int_rate", order = ["A", "B", "C", "D", "E", "F", "G"], data=accepted)

# %%
plt.figure(figsize=(13, 6))
sns.lineplot(x="issue_d", y="int_rate", hue = "grade", data =accepted)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(accepted.iloc[:, :50].corr())

# %%
from sklearn.model_selection import train_test_split

loans = accepted.drop('grade',axis=1)
grade = accepted['grade']
sub_grade = accepted["sub_grade"]
loans_train, loans_test, grade_train, grade_test = train_test_split(loans, grade, test_size=0.2, random_state=42)

# %%
loans_desc = loans_train.merge(grade_train, left_index=True, right_index=True)

# %%
loans_desc.head()
# Out:
#            loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# id
# 126200518     6500.0       6500.0           6475.0   36 months      7.35
# 138779959    16000.0      16000.0          16000.0   60 months     22.35
# 123040056    30000.0      30000.0          30000.0   36 months     17.09
# 72695445      6000.0       6000.0           6000.0   36 months      5.32
# 140239763    20000.0      20000.0          20000.0   60 months     15.02
#
#            installment sub_grade                     emp_title emp_length  \
# id
# 126200518       201.75        A4             Solar Consultant      1 year
# 138779959       445.10        D5                       Teacher  10+ years
# 123040056      1070.93        D1  Director, Product Management   < 1 year
# 72695445        180.69        A1                    bus driver   < 1 year
# 140239763       476.01        C3             Assistant Manager  10+ years
#
#           home_ownership  annual_inc verification_status     issue_d  \
# id
# 126200518       MORTGAGE     78000.0        Not Verified  2017-12-01
# 138779959       MORTGAGE     75000.0            Verified  2018-08-01
# 123040056           RENT    200000.0            Verified  2017-11-01
# 72695445             OWN     33000.0     Source Verified  2016-03-01
# 140239763           RENT     58000.0     Source Verified  2018-09-01
#
#           loan_status pymnt_plan   desc             purpose  \
# id
# 126200518     Current          n  other         credit_card
# 138779959     Current          n  other  debt_consolidation
# 123040056     Current          n  other  debt_consolidation
# 72695445   Fully Paid          n  other  debt_consolidation
# 140239763     Current          n  other  debt_consolidation
#
#                              title addr_state    dti  delinq_2yrs  \
# id
# 126200518  Credit card refinancing         NJ   7.85          0.0
# 138779959       Debt consolidation         NY  24.53          2.0
# 123040056       Debt consolidation         VA  25.79          0.0
# 72695445        Debt consolidation         IL   3.76          0.0
# 140239763       Debt consolidation         NJ  17.61          0.0
#
#           earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# id
# 126200518       2012-11-01           680.0            684.0             0.0
# 138779959       1997-06-01           660.0            664.0             0.0
# 123040056       1998-11-01           705.0            709.0             0.0
# 72695445        1994-06-01           725.0            729.0             0.0
# 140239763       2013-06-01           690.0            694.0             0.0
#
#            open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# id
# 126200518      10.0      0.0     6828.0        29.7       10.0
# 138779959      12.0      0.0    10604.0        54.4       40.0
# 123040056      12.0      0.0    46836.0        82.6       30.0
# 72695445       10.0      0.0     5559.0        14.3       23.0
# 140239763       8.0      0.0    10436.0        39.0       11.0
#
#           initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# id
# 126200518                   f    3963.98        3948.73   3019.610000
# 138779959                   w   14910.95       14910.95   3075.970000
# 123040056                   w   18524.45       18524.45  17160.910000
# 72695445                    w       0.00           0.00   6355.768399
# 140239763                   w   18602.86       18602.86   2822.680000
#
#            total_pymnt_inv  total_rec_prncp  total_rec_int  \
# id
# 126200518          3008.00          2536.02         483.59
# 138779959          3075.97          1089.05        1986.92
# 123040056         17160.91         11475.55        5685.36
# 72695445           6355.77          6000.00         355.77
# 140239763          2822.68          1397.14        1425.54
#
#            total_rec_late_fee  recoveries  collection_recovery_fee  \
# id
# 126200518                 0.0         0.0                      0.0
# 138779959                 0.0         0.0                      0.0
# 123040056                 0.0         0.0                      0.0
# 72695445                  0.0         0.0                      0.0
# 140239763                 0.0         0.0                      0.0
#
#            last_pymnt_amnt last_credit_pull_d  last_fico_range_high  \
# id
# 126200518           201.75         2019-03-01                 659.0
# 138779959           445.10         2019-03-01                 669.0
# 123040056          1070.93         2019-03-01                 684.0
# 72695445            633.67         2019-03-01                 744.0
# 140239763           476.01         2019-03-01                 614.0
#
#            last_fico_range_low  collections_12_mths_ex_med  policy_code  \
# id
# 126200518                655.0                         0.0          1.0
# 138779959                665.0                         0.0          1.0
# 123040056                680.0                         0.0          1.0
# 72695445                 740.0                         0.0          1.0
# 140239763                610.0                         0.0          1.0
#
#           application_type  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# id
# 126200518       Individual             0.0         418.0      13176.0
# 138779959       Individual             0.0           0.0      52491.0
# 123040056       Individual             0.0           0.0     110489.0
# 72695445        Individual             0.0         186.0      95584.0
# 140239763       Individual             0.0           0.0      20180.0
#
#            open_acc_6m  open_act_il  open_il_12m  open_il_24m  \
# id
# 126200518          1.0          2.0          1.0          1.0
# 138779959          2.0          4.0          1.0          3.0
# 123040056          1.0          5.0          2.0          3.0
# 72695445           0.0          0.0          0.0          0.0
# 140239763          0.0          2.0          0.0          1.0
#
#            mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# id
# 126200518                11.0        6348.0     63.0          2.0
# 138779959                11.0       41887.0     56.0          5.0
# 123040056                 5.0       63653.0     52.0          0.0
# 72695445                165.0           0.0      0.0          2.0
# 140239763                13.0        9744.0     70.0          0.0
#
#            open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# id
# 126200518          5.0      3575.0      40.0           23000.0     1.0
# 138779959          6.0      8353.0      56.0           19500.0     2.0
# 123040056          2.0     20420.0      62.0           56700.0     0.0
# 72695445           3.0      2117.0      14.0           39000.0     0.0
# 140239763          5.0      3055.0      39.0           27000.0     0.0
#
#            total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# id
# 126200518          1.0           3.0                   6.0       1318.0
# 138779959          4.0           5.0                  10.0       4374.0
# 123040056          1.0           3.0                   5.0       9207.0
# 72695445           0.0           1.0                   3.0       9558.0
# 140239763          1.0           0.0                   6.0       2522.0
#
#            bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# id
# 126200518         15472.0     30.6                       0.0          0.0
# 138779959          5361.0     65.4                       1.0          0.0
# 123040056          3832.0     92.2                       0.0          0.0
# 72695445          25741.0     17.8                       0.0          0.0
# 140239763          5000.0     30.0                       0.0          0.0
#
#            mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# id
# 126200518                29.0                  61.0                    3.0
# 138779959               128.0                 254.0                    0.0
# 123040056               144.0                 228.0                   14.0
# 72695445                185.0                 261.0                    7.0
# 140239763                55.0                  63.0                   13.0
#
#            mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# id
# 126200518             3.0       0.0                   3.0
# 138779959             0.0       4.0                   9.0
# 123040056             5.0       0.0                  14.0
# 72695445              7.0       1.0                   8.0
# 140239763            13.0       0.0                  18.0
#
#            mths_since_recent_inq  num_accts_ever_120_pd  num_actv_bc_tl  \
# id
# 126200518                   11.0                    0.0             7.0
# 138779959                    3.0                   11.0             3.0
# 123040056                    5.0                    0.0             5.0
# 72695445                     7.0                    0.0             4.0
# 140239763                   13.0                    0.0             4.0
#
#            num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# id
# 126200518              7.0          7.0        7.0        2.0            8.0
# 138779959              5.0          3.0        8.0       11.0            8.0
# 123040056              6.0          5.0       11.0        9.0            7.0
# 72695445               4.0          7.0       13.0        4.0            9.0
# 140239763              6.0          6.0        6.0        2.0            6.0
#
#            num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_30dpd  \
# id
# 126200518            8.0                  7.0      10.0           0.0
# 138779959           25.0                  5.0      12.0           0.0
# 123040056           21.0                  6.0      12.0           0.0
# 72695445            18.0                  4.0      10.0           0.0
# 140239763            9.0                  5.0       8.0           0.0
#
#            num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# id
# 126200518                 0.0                 3.0           100.0
# 138779959                 0.0                 6.0            60.0
# 123040056                 0.0                 2.0            96.7
# 72695445                  0.0                 2.0            95.7
# 140239763                 0.0                 0.0            91.0
#
#            percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# id
# 126200518              14.3                   0.0        0.0          33134.0
# 138779959              33.3                   0.0        0.0          84395.0
# 123040056              80.0                   0.0        0.0         178649.0
# 72695445                0.0                   0.0        0.0         135224.0
# 140239763               0.0                   0.0        0.0          41001.0
#
#            total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# id
# 126200518            13176.0         22300.0                     10134.0
# 138779959            52491.0         15500.0                     64895.0
# 123040056           110489.0         49200.0                    121949.0
# 72695445              5559.0         31300.0                         0.0
# 140239763            20180.0         20000.0                     14001.0
#
#           hardship_flag disbursement_method debt_settlement_flag grade
# id
# 126200518             N           DirectPay                    N     A
# 138779959             N                Cash                    N     D
# 123040056             N                Cash                    N     D
# 72695445              N                Cash                    N     A
# 140239763             N                Cash                    N     C

# %%
drop_no_var = ["hardship_flag", "chargeoff_within_12_mths", "application_type", "policy_code", "out_prncp",
               "pymnt_plan"]

# %%
post_loan_list = ["loan_status", "total_pymnt", "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee",
                  "recoveries", "collection_recovery_fee", "last_pymnt_amnt", "last_credit_pull_d", 
                  "last_fico_range_high", "last_fico_range_low", "debt_settlement_flag", "installment", 
                  "disbursement_method", "hardship_flag"]

# %%
drop_list_obj = ["sub_grade", "emp_title", "title", "addr_state", "earliest_cr_line", 
                 "issue_d", "desc"]

# %%
loans_train.drop((drop_no_var + post_loan_list + drop_list_obj), axis = 1, inplace=True)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
loans_train.head()
# Out:
#            loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# id
# 126200518     6500.0       6500.0           6475.0   36 months      7.35
# 138779959    16000.0      16000.0          16000.0   60 months     22.35
# 123040056    30000.0      30000.0          30000.0   36 months     17.09
# 72695445      6000.0       6000.0           6000.0   36 months      5.32
# 140239763    20000.0      20000.0          20000.0   60 months     15.02
#
#           emp_length home_ownership  annual_inc verification_status  \
# id
# 126200518     1 year       MORTGAGE     78000.0        Not Verified
# 138779959  10+ years       MORTGAGE     75000.0            Verified
# 123040056   < 1 year           RENT    200000.0            Verified
# 72695445    < 1 year            OWN     33000.0     Source Verified
# 140239763  10+ years           RENT     58000.0     Source Verified
#
#                       purpose    dti  delinq_2yrs  fico_range_low  \
# id
# 126200518         credit_card   7.85          0.0           680.0
# 138779959  debt_consolidation  24.53          2.0           660.0
# 123040056  debt_consolidation  25.79          0.0           705.0
# 72695445   debt_consolidation   3.76          0.0           725.0
# 140239763  debt_consolidation  17.61          0.0           690.0
#
#            fico_range_high  inq_last_6mths  open_acc  pub_rec  revol_bal  \
# id
# 126200518            684.0             0.0      10.0      0.0     6828.0
# 138779959            664.0             0.0      12.0      0.0    10604.0
# 123040056            709.0             0.0      12.0      0.0    46836.0
# 72695445             729.0             0.0      10.0      0.0     5559.0
# 140239763            694.0             0.0       8.0      0.0    10436.0
#
#            revol_util  total_acc initial_list_status  out_prncp_inv  \
# id
# 126200518        29.7       10.0                   f        3948.73
# 138779959        54.4       40.0                   w       14910.95
# 123040056        82.6       30.0                   w       18524.45
# 72695445         14.3       23.0                   w           0.00
# 140239763        39.0       11.0                   w       18602.86
#
#            collections_12_mths_ex_med  acc_now_delinq  tot_coll_amt  \
# id
# 126200518                         0.0             0.0         418.0
# 138779959                         0.0             0.0           0.0
# 123040056                         0.0             0.0           0.0
# 72695445                          0.0             0.0         186.0
# 140239763                         0.0             0.0           0.0
#
#            tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  open_il_24m  \
# id
# 126200518      13176.0          1.0          2.0          1.0          1.0
# 138779959      52491.0          2.0          4.0          1.0          3.0
# 123040056     110489.0          1.0          5.0          2.0          3.0
# 72695445       95584.0          0.0          0.0          0.0          0.0
# 140239763      20180.0          0.0          2.0          0.0          1.0
#
#            mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# id
# 126200518                11.0        6348.0     63.0          2.0
# 138779959                11.0       41887.0     56.0          5.0
# 123040056                 5.0       63653.0     52.0          0.0
# 72695445                165.0           0.0      0.0          2.0
# 140239763                13.0        9744.0     70.0          0.0
#
#            open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# id
# 126200518          5.0      3575.0      40.0           23000.0     1.0
# 138779959          6.0      8353.0      56.0           19500.0     2.0
# 123040056          2.0     20420.0      62.0           56700.0     0.0
# 72695445           3.0      2117.0      14.0           39000.0     0.0
# 140239763          5.0      3055.0      39.0           27000.0     0.0
#
#            total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# id
# 126200518          1.0           3.0                   6.0       1318.0
# 138779959          4.0           5.0                  10.0       4374.0
# 123040056          1.0           3.0                   5.0       9207.0
# 72695445           0.0           1.0                   3.0       9558.0
# 140239763          1.0           0.0                   6.0       2522.0
#
#            bc_open_to_buy  bc_util  delinq_amnt  mo_sin_old_il_acct  \
# id
# 126200518         15472.0     30.6          0.0                29.0
# 138779959          5361.0     65.4          0.0               128.0
# 123040056          3832.0     92.2          0.0               144.0
# 72695445          25741.0     17.8          0.0               185.0
# 140239763          5000.0     30.0          0.0                55.0
#
#            mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  \
# id
# 126200518                  61.0                    3.0             3.0
# 138779959                 254.0                    0.0             0.0
# 123040056                 228.0                   14.0             5.0
# 72695445                  261.0                    7.0             7.0
# 140239763                  63.0                   13.0            13.0
#
#            mort_acc  mths_since_recent_bc  mths_since_recent_inq  \
# id
# 126200518       0.0                   3.0                   11.0
# 138779959       4.0                   9.0                    3.0
# 123040056       0.0                  14.0                    5.0
# 72695445        1.0                   8.0                    7.0
# 140239763       0.0                  18.0                   13.0
#
#            num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  \
# id
# 126200518                    0.0             7.0              7.0
# 138779959                   11.0             3.0              5.0
# 123040056                    0.0             5.0              6.0
# 72695445                     0.0             4.0              4.0
# 140239763                    0.0             4.0              6.0
#
#            num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  \
# id
# 126200518          7.0        7.0        2.0            8.0            8.0
# 138779959          3.0        8.0       11.0            8.0           25.0
# 123040056          5.0       11.0        9.0            7.0           21.0
# 72695445           7.0       13.0        4.0            9.0           18.0
# 140239763          6.0        6.0        2.0            6.0            9.0
#
#            num_rev_tl_bal_gt_0  num_sats  num_tl_30dpd  num_tl_90g_dpd_24m  \
# id
# 126200518                  7.0      10.0           0.0                 0.0
# 138779959                  5.0      12.0           0.0                 0.0
# 123040056                  6.0      12.0           0.0                 0.0
# 72695445                   4.0      10.0           0.0                 0.0
# 140239763                  5.0       8.0           0.0                 0.0
#
#            num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# id
# 126200518                 3.0           100.0              14.3
# 138779959                 6.0            60.0              33.3
# 123040056                 2.0            96.7              80.0
# 72695445                  2.0            95.7               0.0
# 140239763                 0.0            91.0               0.0
#
#            pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# id
# 126200518                   0.0        0.0          33134.0
# 138779959                   0.0        0.0          84395.0
# 123040056                   0.0        0.0         178649.0
# 72695445                    0.0        0.0         135224.0
# 140239763                   0.0        0.0          41001.0
#
#            total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# id
# 126200518            13176.0         22300.0                     10134.0
# 138779959            52491.0         15500.0                     64895.0
# 123040056           110489.0         49200.0                    121949.0
# 72695445              5559.0         31300.0                         0.0
# 140239763            20180.0         20000.0                     14001.0

# %%
loans_train = pd.get_dummies(loans_train)

# %% [markdown]
# ### Decission tree train

# %%
from sklearn.tree import DecisionTreeClassifier
grade_class = DecisionTreeClassifier(random_state=0)

# %%
Xtrain = loans_train
ytrain = grade_train

# %%
grade_class.fit(Xtrain, ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cv = cross_val_score(DecisionTreeClassifier(),Xtrain, ytrain,cv=10)

# %%
np.mean(cv)
# Out:
# 0.9873979424055074

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
y_pred = grade_class.predict(loans_test_with_dummies)

# %%
confusion_matrix(grade_test,y_pred)

# %%
print(classification_report(grade_test,y_pred))
